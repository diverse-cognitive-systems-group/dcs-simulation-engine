# %% [markdown]
# # Divergence Calculator
#
# Calculates the divergence *between two characters abilities.*

# %% [markdown]
# ## Setup

# %% [markdown]
# ## Divergence

# %% [markdown]
# pairwise_divergence = divergence(hid_1, hid_2)
