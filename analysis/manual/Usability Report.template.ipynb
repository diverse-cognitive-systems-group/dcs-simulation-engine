# %% [markdown]
# # Usability Report Template

# %% [markdown]
# ## Overview
#
# **Goal:** Identify and reduce usability issues before downstream experiments.
#
# **Context:** Pre-release validation for engine v0.1.0, which includes major GUI changes.

# %% [markdown]
# ## Method

# %% [markdown]
# The DCS-SE was deployed using the run configuration below, which generates a publicly accessible gameplay link.
#
# Participants who accessed the link first completed informed consent and a demographic survey, followed by gameplay assignments randomly distributed across four core games as described in the config. After completing the assigned games, participants were asked to complete a post-study feedback survey.
#
# ```yml
# <paste of usability_ca.yml config contents here>
# ```
#
# Participants were recruited via SONA (a university participant recruitment system) and received course credit. Additional participants were recruited via word of mouth and provided the same gameplay link.

# %% [markdown]
# ## Results

# %% [markdown]
# ### Overview
#
# X players played X games with X characters.

# %%
# run analysis notebook manually or using papermill
# !papermill analyses/Summarize Results.ipynb supplemental/Results Overview.ipynb -p results_path /path/to/result

# %% [markdown]
# #### Player Feedback
#
# Key themes from player feedback include:

# %%
# run analysis notebook manually or using papermill
# !papermill analyses/Summarize Results.ipynb supplemental/Results Overview.ipynb -p results_path /path/to/result

# %% [markdown]
# #### System Performance
#
# No noteworthy performance issues were observed during the study. Turns averaged... etc.

# %% [markdown]
# ## Discussion
